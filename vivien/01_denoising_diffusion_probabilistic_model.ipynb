# %% [markdown]
# # Denoising Diffusion Probabilistic Model
#
# Kernel Author: Minsu Kang
#
# Email: mskang1478@gmail.com

# %%
#!git clone https://github.com/Jackson-Kang/Pytorch-Diffusion-Model-Tutorial.git

# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: jupyter in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (4.67.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.10.9)
# Requirement already satisfied: torch in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.5.1)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.20.1)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (7.5.6)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (7.17.1)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 1)) (4.5.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (26.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from torch->-r requirements.txt (line 4)) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from sympy==1.13.1->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (9.10.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.15.0)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (82.0.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.33.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: tzdata in /opt/anaconda3/envs/ddpm/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.2)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

import numpy as np
np.Inf = np.inf

from tqdm import tqdm
from torchvision.utils import save_image, make_grid
from tqdm import tqdm
from torch.optim import Adam

import math

# %%
# Model Hyperparameters

dataset_path = '~/datasets'

# Device selection: MPS for Apple Silicon, CPU otherwise (no CUDA on Mac)
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device("cpu")

print(f"Using device: {DEVICE}")

dataset = 'MNIST'
img_size = (32, 32, 3)   if dataset == "CIFAR10" else (28, 28, 1) # (width, height, channels)

timestep_embedding_dim = 256
n_layers = 8
hidden_dim = 256
n_timesteps = 1000
beta_minmax=[1e-4, 2e-2]

train_batch_size = 128
inference_batch_size = 64
lr = 5e-5
epochs = 200

seed = 1234

hidden_dims = [hidden_dim for _ in range(n_layers)]
torch.manual_seed(seed)
np.random.seed(seed)
# Out:
# Using device: mps

# %% [markdown]
# ## Step 1. Load (or download) Dataset

# %%
from torchvision.datasets import MNIST, CIFAR10
import torchvision.transforms as transforms
from torch.utils.data import DataLoader


transform = transforms.Compose([
        transforms.ToTensor(),
])

kwargs = {'num_workers': 1, 'pin_memory': True}

if dataset == 'CIFAR10':
    train_dataset = CIFAR10(dataset_path, transform=transform, train=True, download=True)
    test_dataset  = CIFAR10(dataset_path, transform=transform, train=False, download=True)
else:
    train_dataset = MNIST(dataset_path, transform=transform, train=True, download=True)
    test_dataset  = MNIST(dataset_path, transform=transform, train=False, download=True)

train_loader = DataLoader(dataset=train_dataset, batch_size=train_batch_size, shuffle=True, **kwargs)
test_loader  = DataLoader(dataset=test_dataset,  batch_size=inference_batch_size, shuffle=False,  **kwargs)

# %% [markdown]
# ## Step 2. Define our model: Denoising Diffusion Probabilistic Models (DDPMs)

# %% [markdown]
# Sinusoidal embedding for diffusion timestep

# %%
class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, x):
        device = x.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = x[:, None] * emb[None, :]
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)
        return emb

# %% [markdown]
# In this tutorial, we use a simple stacked-convolution model with various dilations instead of UNet-like architecture.

# %%
class ConvBlock(nn.Conv2d):
    """
        Conv2D Block
            Args:
                x: (N, C_in, H, W)
            Returns:
                y: (N, C_out, H, W)
    """

    def __init__(self, in_channels, out_channels, kernel_size, activation_fn=None, drop_rate=0.,
                    stride=1, padding='same', dilation=1, groups=1, bias=True, gn=False, gn_groups=8):

        if padding == 'same':
            padding = kernel_size // 2 * dilation

        super(ConvBlock, self).__init__(in_channels, out_channels, kernel_size,
                                            stride=stride, padding=padding, dilation=dilation,
                                            groups=groups, bias=bias)

        self.activation_fn = nn.SiLU() if activation_fn else None
        self.group_norm = nn.GroupNorm(gn_groups, out_channels) if gn else None

    def forward(self, x, time_embedding=None, residual=False):

        if residual:
            # in the paper, diffusion timestep embedding was only applied to residual blocks of U-Net
            x = x + time_embedding
            y = x
            x = super(ConvBlock, self).forward(x)
            y = y + x
        else:
            y = super(ConvBlock, self).forward(x)
        y = self.group_norm(y) if self.group_norm is not None else y
        y = self.activation_fn(y) if self.activation_fn is not None else y

        return y

# %%
class Denoiser(nn.Module):

    def __init__(self, image_resolution, hidden_dims=[256, 256], diffusion_time_embedding_dim = 256, n_times=1000):
        super(Denoiser, self).__init__()

        _, _, img_C = image_resolution

        self.time_embedding = SinusoidalPosEmb(diffusion_time_embedding_dim)

        self.in_project = ConvBlock(img_C, hidden_dims[0], kernel_size=7)

        self.time_project = nn.Sequential(
                                 ConvBlock(diffusion_time_embedding_dim, hidden_dims[0], kernel_size=1, activation_fn=True),
                                 ConvBlock(hidden_dims[0], hidden_dims[0], kernel_size=1))

        self.convs = nn.ModuleList([ConvBlock(in_channels=hidden_dims[0], out_channels=hidden_dims[0], kernel_size=3)])

        for idx in range(1, len(hidden_dims)):
            self.convs.append(ConvBlock(hidden_dims[idx-1], hidden_dims[idx], kernel_size=3, dilation=3**((idx-1)//2),
                                                    activation_fn=True, gn=True, gn_groups=8))

        self.out_project = ConvBlock(hidden_dims[-1], out_channels=img_C, kernel_size=3)


    def forward(self, perturbed_x, diffusion_timestep):
        y = perturbed_x

        diffusion_embedding = self.time_embedding(diffusion_timestep)
        diffusion_embedding = self.time_project(diffusion_embedding.unsqueeze(-1).unsqueeze(-2))

        y = self.in_project(y)

        for i in range(len(self.convs)):
            y = self.convs[i](y, diffusion_embedding, residual = True)

        y = self.out_project(y)

        return y

model = Denoiser(image_resolution=img_size,
                 hidden_dims=hidden_dims,
                 diffusion_time_embedding_dim=timestep_embedding_dim,
                 n_times=n_timesteps).to(DEVICE)

# %% [markdown]
# ### Define Gaussian Diffusion

# %%
class Diffusion(nn.Module):
    def __init__(self, model, image_resolution=[32, 32, 3], n_times=1000, beta_minmax=[1e-4, 2e-2], device=None):

        super(Diffusion, self).__init__()

        if device is None:
            device = DEVICE

        self.n_times = n_times
        self.img_H, self.img_W, self.img_C = image_resolution

        self.model = model

        # define linear variance schedule(betas)
        beta_1, beta_T = beta_minmax
        betas = torch.linspace(start=beta_1, end=beta_T, steps=n_times).to(device) # follows DDPM paper
        self.sqrt_betas = torch.sqrt(betas)

        # define alpha for forward diffusion kernel
        self.alphas = 1 - betas
        self.sqrt_alphas = torch.sqrt(self.alphas)
        alpha_bars = torch.cumprod(self.alphas, dim=0)
        self.sqrt_one_minus_alpha_bars = torch.sqrt(1-alpha_bars)
        self.sqrt_alpha_bars = torch.sqrt(alpha_bars)

        self.device = device

    def extract(self, a, t, x_shape):
        """
            from lucidrains' implementation
                https://github.com/lucidrains/denoising-diffusion-pytorch/blob/beb2f2d8dd9b4f2bd5be4719f37082fe061ee450/denoising_diffusion_pytorch/denoising_diffusion_pytorch.py#L376
        """
        b, *_ = t.shape
        out = a.gather(-1, t)
        return out.reshape(b, *((1,) * (len(x_shape) - 1)))

    def scale_to_minus_one_to_one(self, x):
        # according to the DDPMs paper, normalization seems to be crucial to train reverse process network
        return x * 2 - 1

    def reverse_scale_to_zero_to_one(self, x):
        return (x + 1) * 0.5

    def make_noisy(self, x_zeros, t):
        # perturb x_0 into x_t (i.e., take x_0 samples into forward diffusion kernels)
        epsilon = torch.randn_like(x_zeros).to(self.device)

        sqrt_alpha_bar = self.extract(self.sqrt_alpha_bars, t, x_zeros.shape)
        sqrt_one_minus_alpha_bar = self.extract(self.sqrt_one_minus_alpha_bars, t, x_zeros.shape)

        # Let's make noisy sample!: i.e., Forward process with fixed variance schedule
        #      i.e., sqrt(alpha_bar_t) * x_zero + sqrt(1-alpha_bar_t) * epsilon
        noisy_sample = x_zeros * sqrt_alpha_bar + epsilon * sqrt_one_minus_alpha_bar

        return noisy_sample.detach(), epsilon


    def forward(self, x_zeros):
        x_zeros = self.scale_to_minus_one_to_one(x_zeros)

        B, _, _, _ = x_zeros.shape

        # (1) randomly choose diffusion time-step
        t = torch.randint(low=0, high=self.n_times, size=(B,)).long().to(self.device)

        # (2) forward diffusion process: perturb x_zeros with fixed variance schedule
        perturbed_images, epsilon = self.make_noisy(x_zeros, t)

        # (3) predict epsilon(noise) given perturbed data at diffusion-timestep t.
        pred_epsilon = self.model(perturbed_images, t)

        return perturbed_images, epsilon, pred_epsilon


    def denoise_at_t(self, x_t, timestep, t):
        B, _, _, _ = x_t.shape
        if t > 1:
            z = torch.randn_like(x_t).to(self.device)
        else:
            z = torch.zeros_like(x_t).to(self.device)

        # at inference, we use predicted noise(epsilon) to restore perturbed data sample.
        epsilon_pred = self.model(x_t, timestep)

        alpha = self.extract(self.alphas, timestep, x_t.shape)
        sqrt_alpha = self.extract(self.sqrt_alphas, timestep, x_t.shape)
        sqrt_one_minus_alpha_bar = self.extract(self.sqrt_one_minus_alpha_bars, timestep, x_t.shape)
        sqrt_beta = self.extract(self.sqrt_betas, timestep, x_t.shape)

        # denoise at time t, utilizing predicted noise
        x_t_minus_1 = 1 / sqrt_alpha * (x_t - (1-alpha)/sqrt_one_minus_alpha_bar*epsilon_pred) + sqrt_beta*z

        return x_t_minus_1.clamp(-1., 1)

    def sample(self, N):
        # start from random noise vector, x_0 (for simplicity, x_T declared as x_t instead of x_T)
        x_t = torch.randn((N, self.img_C, self.img_H, self.img_W)).to(self.device)

        # autoregressively denoise from x_T to x_0
        #     i.e., generate image from noise, x_T
        for t in range(self.n_times-1, -1, -1):
            timestep = torch.tensor([t]).repeat_interleave(N, dim=0).long().to(self.device)
            x_t = self.denoise_at_t(x_t, timestep, t)

        # denormalize x_0 into 0 ~ 1 ranged values.
        x_0 = self.reverse_scale_to_zero_to_one(x_t)

        return x_0


diffusion = Diffusion(model, image_resolution=img_size, n_times=n_timesteps,
                      beta_minmax=beta_minmax, device=DEVICE).to(DEVICE)

optimizer = Adam(diffusion.parameters(), lr=lr)
denoising_loss = nn.MSELoss()

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print("Number of model parameters: ", count_parameters(diffusion))
# Out:
# Number of model parameters:  4870913

# %% [markdown]
# ### Visualizing forward process

# %%
model.eval()
for batch_idx, (x, _) in enumerate(test_loader):
    x = x.to(DEVICE)
    perturbed_images, epsilon, pred_epsilon = diffusion(x)
    perturbed_images = diffusion.reverse_scale_to_zero_to_one(perturbed_images)
    break

# %%
def show_image(x, idx):
    fig = plt.figure()
    plt.imshow(x[idx].transpose(0, 1).transpose(1, 2).detach().cpu().numpy())

# %%
show_image(perturbed_images, idx=0)

# %%
show_image(perturbed_images, idx=1)

# %%
show_image(perturbed_images, idx=2)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Step 3. Train Denoising Diffusion Probabilistic Models(DDPMs)

# %%
print("Start training DDPMs...")
model.train()

epochs = 10 

for epoch in range(epochs):
    noise_prediction_loss = 0
    for batch_idx, (x, _) in tqdm(enumerate(train_loader), total=len(train_loader)):
        optimizer.zero_grad()

        x = x.to(DEVICE)

        noisy_input, epsilon, pred_epsilon = diffusion(x)
        loss = denoising_loss(pred_epsilon, epsilon)

        noise_prediction_loss += loss.item()

        loss.backward()
        optimizer.step()

    print("\tEpoch", epoch + 1, "complete!", "\tDenoising Loss: ", noise_prediction_loss / batch_idx)

print("Finish!!")
# Out:
# Start training DDPMs...
# 100%|██████████| 469/469 [19:22<00:00,  2.48s/it]
# 	Epoch 1 complete! 	Denoising Loss:  0.09166477944176549
#  13%|█▎        | 62/469 [02:31<16:37,  2.45s/it]Exception ignored in: libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe<generator object tqdm.__iter__ at 0x15de81340>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/std.py", line 1196, in __iter__
#
#     self.close()
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/std.py", line 1302, in close
#     self.display(pos=0)
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/std.py", line 1495, in display
#     self.sp(self.__str__() if msg is None else msg)
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/std.py", line 459, in print_status
#     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/std.py", line 453, in fp_write
#     fp_flush()
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/tqdm/utils.py", line 196, in inner
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/ipykernel/iostream.py", line 670, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/ipykernel/iostream.py", line 339, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/zmq/sugar/socket.py", line 698, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/_zmq.py", line 1152, in zmq.backend.cython._zmq.Socket.send
#   File "zmq/backend/cython/_zmq.py", line 1200, in zmq.backend.cython._zmq.Socket.send
#   File "zmq/backend/cython/_zmq.py", line 1473, in zmq.backend.cython._zmq._send_copy
#   File "zmq/backend/cython/_zmq.py", line 1468, in zmq.backend.cython._zmq._send_copy
#   File "zmq/backend/cython/_zmq.py", line 179, in zmq.backend.cython._zmq._check_rc
#   File "/opt/anaconda3/envs/ddpm/lib/python3.11/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 83614) is killed by signal: Abort trap: 6.

# %% [markdown]
# ## Step 4. Sample images from noise.

# %%
model.eval()

with torch.no_grad():
    generated_images = diffusion.sample(N=inference_batch_size)

# %%
show_image(generated_images, idx=0)

# %%
show_image(generated_images, idx=1)

# %%
show_image(generated_images, idx=2)

# %%
show_image(generated_images, idx=3)

# %%
show_image(generated_images, idx=4)

# %%
show_image(generated_images, idx=5)

# %% [markdown]
# ### Comparison with ground-truth samples

# %%
def draw_sample_image(x, postfix):

    plt.figure(figsize=(8,8))
    plt.axis("off")
    plt.title("Visualization of {}".format(postfix))
    plt.imshow(np.transpose(make_grid(x.detach().cpu(), padding=2, normalize=True), (1, 2, 0)))

# %%
draw_sample_image(perturbed_images, "Perturbed Images")

# %%
draw_sample_image(generated_images, "Generated Images")

# %%
draw_sample_image(x[:inference_batch_size], "Ground-truth Images")
